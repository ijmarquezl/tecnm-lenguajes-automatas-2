# %% [markdown]
# # Lenguajes y Autómatas II (SCD-1016)
# ## Sesión 31: Introducción a Ensamblador x86-64
# **Docente Titular:** MCC. Iván Márquez Larios (`ijmarquezl`)
# **Repositorio Maestro:** `https://github.com/ijmarquezl/tecnm-lenguajes-automatas-2`
#
# ---
# ### Protocolo de la Sesión
# 1. **Fase 1 (El Artesano):** Resolver a mano: *Mapeo de TAC a instrucciones mov/add/sub*.
# 2. **Fase 2 (El Científico):** Definir contrato C-R-E-O: *Sintaxis estándar de ensamblador GNU* y formular prompt.
# 3. **Fase 3 (El Auditor):** Someter la solución al Test Harness: *Ejecución de operaciones aritméticas en CPU*.
# 4. **Entrega:** Documentar en `auditorias/auditoria_sesion31.md`.

# %% [markdown]
# ### Paso 0: Inicialización del Entorno (C y Rust)

# %%
import os
if os.system('which rustc > /dev/null 2>&1') != 0:
    print('⏳ Instalando Rust en Colab...')
    # !apt-get update -qq && apt-get install -y -qq rustc > /dev/null 2>&1
print('✅ Entorno listo:')
# !gcc --version | head -n 1
# !rustc --version

# %% [markdown]
# ---
# ## SECCIÓN A: TRACK C
# ### Fase 1: El Artesano (15 min - Sin IA)
# **Reto:** Mapeo de TAC a instrucciones mov/add/sub

# %%
# %%writefile artesano_sesion31_c.c
# #include <stdio.h>
# #include <stdlib.h>
#
# // TODO: Implementación manual
# int main() {
#     printf("[SESION 31] Reto Artesano: Mapeo de TAC a instrucciones mov/add/sub\n");
#     return 0;
# }

# %%
# !gcc -Wall -Wextra artesano_sesion31_c.c -o bin_c && ./bin_c

# %% [markdown]
# ### Fase 2: El Científico (Prompting C-R-E-O)
# Pega aquí la implementación optimizada propuesta por la IA:

# %%
# %%writefile ia_sesion31_c.c
# #include <stdio.h>
#
# // Pega aquí el código generado por la IA para auditarlo

# %% [markdown]
# ### Fase 3: El Auditor (Test Harness en C)
# Pruebas de estrés: Ejecución de operaciones aritméticas en CPU

# %%
# %%writefile harness_sesion31_c.c
# #include <stdio.h>
# #include <assert.h>
#
# int main() {
#     printf("=== AUDITORIA CRITICA: SESION 31 ===\n");
#     printf("Ejecutando pruebas de estres... PASO ✅\n");
#     return 0;
# }

# %%
# !gcc -Wall -Wextra harness_sesion31_c.c -o test_bin && ./test_bin
