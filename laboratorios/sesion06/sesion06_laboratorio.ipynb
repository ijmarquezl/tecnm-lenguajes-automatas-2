# %% [markdown]
# # Lenguajes y Autómatas II (SCD-1016)
# ## Sesión 06: Sistema de Tipos Primitivos
# **Docente Titular:** MCC. Iván Márquez Larios (`ijmarquezl`)
# **Repositorio Maestro:** `https://github.com/ijmarquezl/tecnm-lenguajes-automatas-2`
#
# ---
# ### Protocolo de la Sesión
# 1. **Fase 1 (El Artesano):** Resolver a mano: *Chequeo de compatibilidad de tipos*.
# 2. **Fase 2 (El Científico):** Definir contrato C-R-E-O: *Matriz de compatibilidad estática* y formular prompt.
# 3. **Fase 3 (El Auditor):** Someter la solución al Test Harness: *Rechazo de asignaciones incompatibles*.
# 4. **Entrega:** Documentar en `auditorias/auditoria_sesion06.md`.

# %% [markdown]
# ### Paso 0: Inicialización del Entorno (C y Rust)

# %%
import os
if os.system('which rustc > /dev/null 2>&1') != 0:
    print('⏳ Instalando Rust en Colab...')
    # !apt-get update -qq && apt-get install -y -qq rustc > /dev/null 2>&1
print('✅ Entorno listo:')
# !gcc --version | head -n 1
# !rustc --version

# %% [markdown]
# ---
# ## SECCIÓN A: TRACK C
# ### Fase 1: El Artesano (15 min - Sin IA)
# **Reto:** Chequeo de compatibilidad de tipos

# %%
# %%writefile artesano_sesion06_c.c
# #include <stdio.h>
# #include <stdlib.h>
#
# // TODO: Implementación manual
# int main() {
#     printf("[SESION 06] Reto Artesano: Chequeo de compatibilidad de tipos\n");
#     return 0;
# }

# %%
# !gcc -Wall -Wextra artesano_sesion06_c.c -o bin_c && ./bin_c

# %% [markdown]
# ### Fase 2: El Científico (Prompting C-R-E-O)
# Pega aquí la implementación optimizada propuesta por la IA:

# %%
# %%writefile ia_sesion06_c.c
# #include <stdio.h>
#
# // Pega aquí el código generado por la IA para auditarlo

# %% [markdown]
# ### Fase 3: El Auditor (Test Harness en C)
# Pruebas de estrés: Rechazo de asignaciones incompatibles

# %%
# %%writefile harness_sesion06_c.c
# #include <stdio.h>
# #include <assert.h>
#
# int main() {
#     printf("=== AUDITORIA CRITICA: SESION 06 ===\n");
#     printf("Ejecutando pruebas de estres... PASO ✅\n");
#     return 0;
# }

# %%
# !gcc -Wall -Wextra harness_sesion06_c.c -o test_bin && ./test_bin
