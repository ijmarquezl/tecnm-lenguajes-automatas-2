# %% [markdown]
# # Lenguajes y Autómatas II (SCD-1016)
# ## Sesión 28: Optimización: Constant Folding
# **Docente Titular:** MCC. Iván Márquez Larios (`ijmarquezl`)
# **Repositorio Maestro:** `https://github.com/ijmarquezl/tecnm-lenguajes-automatas-2`
#
# ---
# ### Protocolo de la Sesión
# 1. **Fase 1 (El Artesano):** Resolver a mano: *Plegado y simplificación de constantes*.
# 2. **Fase 2 (El Científico):** Definir contrato C-R-E-O: *Reducción estática en compilación* y formular prompt.
# 3. **Fase 3 (El Auditor):** Someter la solución al Test Harness: *Simplificación de expresiones constantes*.
# 4. **Entrega:** Documentar en `auditorias/auditoria_sesion28.md`.

# %% [markdown]
# ### Paso 0: Inicialización del Entorno (C y Rust)

# %%
import os
if os.system('which rustc > /dev/null 2>&1') != 0:
    print('⏳ Instalando Rust en Colab...')
    # !apt-get update -qq && apt-get install -y -qq rustc > /dev/null 2>&1
print('✅ Entorno listo:')
# !gcc --version | head -n 1
# !rustc --version

# %% [markdown]
# ---
# ## SECCIÓN A: TRACK C
# ### Fase 1: El Artesano (15 min - Sin IA)
# **Reto:** Plegado y simplificación de constantes

# %%
# %%writefile artesano_sesion28_c.c
# #include <stdio.h>
# #include <stdlib.h>
#
# // TODO: Implementación manual
# int main() {
#     printf("[SESION 28] Reto Artesano: Plegado y simplificación de constantes\n");
#     return 0;
# }

# %%
# !gcc -Wall -Wextra artesano_sesion28_c.c -o bin_c && ./bin_c

# %% [markdown]
# ### Fase 2: El Científico (Prompting C-R-E-O)
# Pega aquí la implementación optimizada propuesta por la IA:

# %%
# %%writefile ia_sesion28_c.c
# #include <stdio.h>
#
# // Pega aquí el código generado por la IA para auditarlo

# %% [markdown]
# ### Fase 3: El Auditor (Test Harness en C)
# Pruebas de estrés: Simplificación de expresiones constantes

# %%
# %%writefile harness_sesion28_c.c
# #include <stdio.h>
# #include <assert.h>
#
# int main() {
#     printf("=== AUDITORIA CRITICA: SESION 28 ===\n");
#     printf("Ejecutando pruebas de estres... PASO ✅\n");
#     return 0;
# }

# %%
# !gcc -Wall -Wextra harness_sesion28_c.c -o test_bin && ./test_bin
